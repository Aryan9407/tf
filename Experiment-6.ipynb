# %% [markdown]
# Shakshi Singh Rajput

# %% [markdown]
# U21EC138

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
iris=datasets.load_iris()
X=iris.data[:,:2]
Y=iris.target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)
plt.figure(figsize=(18, 6))

# %%
svm_classifier = SVC()

# %%
svm_classifier.fit(X_train, Y_train)
# Out:
# SVC()

# %%
Y_pred = svm_classifier.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='weighted')
recall = recall_score(Y_test, Y_pred, average='weighted')
f1 = f1_score(Y_test, Y_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.93
# Precision: 0.95
# Recall: 0.93
# F1 Score: 0.94

# %% [markdown]
# using 'linear', 'poly' and 'rbf' kernels

# %%
kernels = ['linear', 'rbf', 'poly']

# %%
for kernel in kernels:
    # Create an SVM classifier with the specified kernel
    svm_classifier = SVC(kernel=kernel)
    
    # Train the model on the training data
    svm_classifier.fit(X_train, Y_train)
    
    # Make predictions on the testing data
    Y_pred = svm_classifier.predict(X_test)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(Y_test, Y_pred)
    precision = precision_score(Y_test, Y_pred, average='weighted')
    recall = recall_score(Y_test, Y_pred, average='weighted')
    f1 = f1_score(Y_test, Y_pred, average='weighted')
    

    print(f"Kernel: {kernel}")
    print(f"  Accuracy: {accuracy:.2f}")
    print(f"  Precision: {precision:.2f}")
    print(f"  Recall: {recall:.2f}")
    print(f"  F1 Score: {f1:.2f}")
# Out:
# Kernel: linear
#   Accuracy: 0.87
#   Precision: 0.92
#   Recall: 0.87
#   F1 Score: 0.87
# Kernel: rbf
#   Accuracy: 0.93
#   Precision: 0.95
#   Recall: 0.93
#   F1 Score: 0.94
# Kernel: poly
#   Accuracy: 0.87
#   Precision: 0.92
#   Recall: 0.87
#   F1 Score: 0.87

# %%
import numpy as np
import matplotlib.pyplot as plt

for i, kernel in enumerate(kernels):
    # Set up a figure for plotting
    plt.figure(figsize=(15, 5))
    # Create an SVM classifier with a specific kernel
    svm_classifier = SVC(kernel=kernel)
    
    # Train the model
    svm_classifier.fit(X_train, Y_train)
    
    # Make predictions on the testing data
    y_pred = svm_classifier.predict(X_test)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(Y_test, Y_pred)
    f1 = f1_score(Y_test, Y_pred, average='weighted')
    precision = precision_score(Y_test, Y_pred, average='weighted')
    recall = recall_score(Y_test, Y_pred, average='weighted')
    
    # Print the evaluation metrics for the current kernel
    print(f"\nKernel: {kernel}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"F1 Score: {f1:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")

    # Plot decision boundary and scatter plot of data points
    plt.subplot(1, 3, i + 1)  # Create subplots for each kernel
    plt.title(f'Kernel: {kernel} (Accuracy: {accuracy:.2f})')
    
    # Create a mesh grid for plotting decision boundary
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))
    
    # Plot the decision boundary by assigning a color to each point in the mesh grid
    Z = svm_classifier.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    
    # Scatter plot of the training points
    plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train, edgecolors='k', cmap=plt.cm.coolwarm, s=20)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test, edgecolors='k', cmap=plt.cm.coolwarm, s=50, marker='x')

    plt.tight_layout()
    plt.show()
# Out:
# Kernel: linear
# Accuracy: 0.87
# F1 Score: 0.87
# Precision: 0.92
# Recall: 0.87
# C:\Users\Shakshi Singh\AppData\Local\Temp\ipykernel_22608\1081099460.py:46: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test, edgecolors='k', cmap=plt.cm.coolwarm, s=50, marker='x')
# Kernel: rbf
# Accuracy: 0.87
# F1 Score: 0.87
# Precision: 0.92
# Recall: 0.87
# C:\Users\Shakshi Singh\AppData\Local\Temp\ipykernel_22608\1081099460.py:46: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test, edgecolors='k', cmap=plt.cm.coolwarm, s=50, marker='x')
# Kernel: poly
# Accuracy: 0.87
# F1 Score: 0.87
# Precision: 0.92
# ...

# %% [markdown]
# Conclusion:
#
# The Support Vector Machine (SVM) proved effective for classification, handling both linear and non-linear tasks with different kernels. Hyperparameter tuning enhanced performance, and SVM demonstrated strong generalization, often outperforming other classifiers in high-dimensional spaces. Its ability to work well with small to medium-sized datasets made it a reliable choice for various classification problems.
